# %%
#1.	Write a Python program that stores your age as an integer, your height in meters as a float,
#and a complex number of your choice. Print the value and the type() of each variable.

age = 21
height = 5.2
i = complex(1,5)
print ("Age is " ,age,type(age))
print("Height is",height, type(height))
print ("complex number is ",i,type(i))
# Out:
# Age is  21 <class 'int'>
# Height is 5.2 <class 'float'>
# complex number is  (1+5j) <class 'complex'>

# %%
#2.	Take two integer variables a = 7 and b = 2. Compute and print the results of a / b and a // b. 
#Explain in a comment why the two results have different data types.
a = 7
b = 2
print("Using Single Slash Answer will be :",a/b) #single slash operator simple division krta hai answer float mai ata hai
print("Using double slash Answer will be :",a//b)#Double slash operator floor division perform krta hai or output int mai deta hai
# Out:
# Using Single Slash Answer will be : 3.5
# Using double slash Answer will be : 3

# %%
#3.	Given the variable value = 0, predict and then verify using bool(value) whether the following are truthy or falsy: 0, 0.0, "", [],
#None, and "False" (the string). Print each result.
num = 0
print("Answer for bool(0) is",bool(0))
print("Answer for bool(0.0) is",bool(0.0))
print("Answer for bool("'""'") is",bool(""))
print("Answer for bool([]) is",bool([]))
print("Answer for bool(None) is",bool(None))
print("Answer for bool(False) is",bool("False"))
# Out:
# Answer for bool(0) is False
# Answer for bool(0.0) is False
# Answer for bool("") is False
# Answer for bool([]) is False
# Answer for bool(None) is False
# Answer for bool(False) is True

# %%
#4.	Booleans behave like integers in arithmetic. Without running the code first, predict the output of: result = True + True + False * 10. Then run
#it in Python to confirm your answer, and explain the reasoning in a comment.

result = True + True + False * 10
print(result)
# numeric value true is 1 and numeric value of false is 0.
# true + true = 1 + 1 = 2
# false * 10 = 0 * 10 = 0
#so 2 + 0 = 2 
# 2 will be answer
# Out:
# 2

# %%
#5.	Write a program that takes a string number = "45" and converts it to an int and then to a float. Print the type and value after each conversion.
#Then explain the difference between implicit and explicittype conversion using this example.
num = "45"
print(num,"is the real num and its type is",type(num))
int_num = int(num)
print("Converting to Int Data Type , after conversion data type of num is ",type(int_num))
float_num = float(int_num)
print("Converting to float Data Type , after conversion data type of num is ",type(float_num))
# Out:
# 45 is the real num and its type is <class 'str'>
# Converting to Int Data Type , after conversion data type of num is  <class 'int'>
# Converting to float Data Type , after conversion data type of num is  <class 'float'>

# %%
#6.	A user enters two numbers as strings: num1 = "12" and num2 = "8". Write code that correctly adds them as numbers (not strings)
#and prints the sum along with its data type.
num1 = "12"
num2 = "8"
num1 = int(num1)
num2 = int(num2)
print (type(num1),type(num2))
#num1 or num2 ko int mai convert kiya hai ab sum kain gy
sum = num1+num2
print("Sum of Two Numbers is",sum ,"and DataType of sum is ",type(sum))
# Out:
# <class 'int'> <class 'int'>
# Sum of Two Numbers is 20 and DataType of sum is  <class 'int'>

# %%
#7.	Create two complex numbers z1 = 2 + 3j and z2 = 1 - 4j. Write a program to compute and print their sum, difference, and product.
z1=2+3j
z2=1-4j
print("Two Complex Numbers are :",z1,z2)
sum = z1+z2
dif = z1-z2
prod = z1*z2
print("Sum of two complex numbers is :",sum)
print("Difference of two complex numbers is :",dif)
print("Product of two complex numbers is :",prod)
# Out:
# Two Complex Numbers are : (2+3j) (1-4j)
# Sum of two complex numbers is : (3-1j)
# Difference of two complex numbers is : (1+7j)
# Product of two complex numbers is : (14-5j)

# %%
#8.	Given num1 = 17 and num2 = 5, write a single program that prints the results of all seven arithmetic operators (+, -, *, /, //, %, **)
#applied to num1 and num2,with a clear label for each line.
num1 = 17
num2 = 5
print("Addition :", num1+num2)
print("Subtraction :", num1-num2)
print("Multiplication :", num1*num2)
print("Division :", num1/num2)
print("Floor Division :", num1//num2)
print("Modulus :", num1 % num2)
print("Power :", num1**num2)
# Out:
# Addition : 22
# Subtraction : 12
# Multiplication : 85
# Division : 3.4
# Floor Division : 3
# Modulus : 2
# Power : 1419857

# %%
#9.	Start with x = 6. Using only assignment operators (not x = x op value), apply the following operations in order
# and print x after each step: multiply by 4, subtract 9, floor divide by 3, raise to the power of 2.What is the final value of x?
x = 6
x *= 4
print("After Multiplying:", x)
x -= 9
print("After Subtracting:", x)
x //= 3
print("After Floor Division:", x)
x **= 2
print("After Power:", x)
print("Final Value:", x)
# Out:
# After Multiplying: 24
# After Subtracting: 15
# After Floor Division: 5
# After Power: 25
# Final Value: 25

# %%
#10.	Explain, with a short code example, the difference between the / and // operators in Python when 
#    both operands are integers versus when one operand is a float.
print("Division with Integer values:")
print("7 / 2 =", 7 / 2)#normal division answer in floating value
print("7 // 2 =", 7 // 2)
print("\nDivision With Float values:")
print("7.0 / 2 =", 7.0 / 2)#floor division answer in integer value
print("7.0 // 2 =", 7.0 // 2)
# Out:
# Division with Integer values:
# 7 / 2 = 3.5
# 7 // 2 = 3
#
# Division With Float values:
# 7.0 / 2 = 3.5
# 7.0 // 2 = 3.0

# %%
#11.	Given price1 = 250.50 and price2 = 250.5, write a program that checks and prints the result of all
# six comparison operators (>, <, ==, !=, >=, <=)applied to price1 and price2. Are the two values considered equal? Explain why.
price1 = 250.50
price2 = 250.5
print("price1 > price2:", price1 > price2)
print("price1 < price2:", price1 < price2)
print("price1 == price2:", price1 == price2)#250.50 aur 250.5 mathematically same value hain Decimal ke end par zero value ko change nahi karta.
print("price1 != price2:", price1 != price2)
print("price1 >= price2:", price1 >= price2)
print("price1 <= price2:", price1 <= price2)
# Out:
# price1 > price2: False
# price1 < price2: False
# price1 == price2: True
# price1 != price2: False
# price1 >= price2: True
# price1 <= price2: True

# %%
#12.	Write a program that asks the user to enter two numbers and prints which one is greater, or if they are equal, 
#    using only comparison operators and print() (no if statements).
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("First number is greater:", num1 > num2)
print("Second number is greater:", num2 > num1)
print("Both numbers are equal:", num1 == num2)
# Out:
# Enter first number:  10
# Enter second number:  12
# First number is greater: False
# Second number is greater: True
# Both numbers are equal: False

# %%
#13.	A shopping cart total is stored as cart_total = 3499.75 and a discount threshold is min_for_discount = 3000. Using a comparison operator,
#   write a single line of code that storesTrue or False in a variable eligible_for_discount indicating whether the cart qualifies for a discount,
#    and print the result.
cart_total = 3499.75
min_for_discount = 3000
eligible_for_discount = cart_total >= min_for_discount
print("Eligible for Discount:", eligible_for_discount)
# Out:
# Eligible for Discount: True
