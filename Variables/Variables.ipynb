# %%
# Q 1
name="Ali Hassan"
Age=21
Favlang="Python"
print(f"My Name is {name}, I am {Age} years Old and my Favourite Programming Language is {Favlang}.")
# Out:
# My Name is Ali Hassan, I am 21 years Old and my Favourite Programming Language is Python.

# %%
#Q 2
a = 10 
b = 20
#swaping without 3rd no 
a , b = b, a
print ("a = ",a)
print ("b = ",b)
# Out:
# a =  20
# b =  10

# %%
# Q 3
x , y , z = 7 , 14 , 21
sum = x + y + z
print("Sum of Numbers is : " ,sum)
# Out:
# Sum of Numbers is :  42

# %%
# Q 4
number = 20
decimal = 2.5
text = "Ali Hassan"
status = True
#using fucntion type 
print(type(number))
print(type(decimal))
print(type(text))
print(type(status))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
# Q 5
number = "42"
number = int(number)
answer = number + 8
print ("Sum after adding string and int = ",answer)
# Out:
# Sum after adding string and int =  50

# %%
# Q 6
fist_name = "Jonas"
last_name = "Kazlauskas" 
ful_name = fist_name + " " + last_name 
print("Hello,",ful_name)
# Out:
# Hello, Jonas Kazlauskas

# %%
# Q 7
age_year = 20
age_month = age_year*12
age_days = age_year*365
age_hours = age_year*365*24

print("Age in Years is ",age_year)
print("Age in Months is " ,age_month)
print("Age in Days is ",age_days)
print("Age in Hours is ",age_hours)
# Out:
# Age in Years is  20
# Age in Months is  240
# Age in Days is  7300
# Age in Hours is  175200

# %%
# Q 8
#output guesing 
a = 5
b = "5"
print(a==b)    #ye false ho ga bcz a int hai or b string hai 
print(a==int(b)) # is mai a hmary ps int hai or b string but int function b ko string sy int mai convert kry ga so it will be true
print(str(a)==b) # is mai b string hai or a int or string function sy a string mai convert ho jy ga then both values will be string so answer will be True
# Out:
# False
# True
# True
